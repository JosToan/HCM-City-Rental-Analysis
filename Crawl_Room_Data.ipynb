# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_listing_links(page_url):
    response = requests.get(page_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Tìm tất cả các thẻ <h3 class="post-title"> rồi trích xuất href từ thẻ <a>
    listings = soup.select("h3.post-title a")  # Lấy tất cả các thẻ <a> trong <h3 class="post-title">
    
    listing_links = []
    for listing in listings:
        link = listing['href']  # Lấy đường dẫn từ thuộc tính href
        full_link = f"https://phongtro123.com{link}"  # Thêm domain vào đường dẫn tương đối
        listing_links.append(full_link)
    
    return listing_links

# %%
def get_room_details(listing_url):
    response = requests.get(listing_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # 1. Tiêu đề và rating
    title_tag = soup.select_one("h1.page-h1 a")
    title = title_tag.get_text() if title_tag else 'N/A'
    
    rating_tag = soup.select_one("h1.page-h1 .star")
    rating = rating_tag.get('class')[1].split('-')[1] if rating_tag else 'N/A'  # Lấy số lượng sao từ class star-5
    
    # 2. Địa chỉ
    address_tag = soup.select_one("address.post-address")
    address = address_tag.get_text().replace("Địa chỉ:", "").strip() if address_tag else 'N/A'

    # 3. Giá
    price_tag = soup.select_one("div.item.price span")
    price = price_tag.get_text() if price_tag else 'N/A'

    # 4. Diện tích
    area_tag = soup.select_one("div.item.acreage span")
    area = area_tag.get_text().strip() if area_tag else 'N/A'

    # 5. ID phòng trọ
    id_tag = soup.select_one("div.item.hashtag span")
    room_id = id_tag.get_text() if id_tag else 'N/A'

    # 6. Thời gian đăng
    published_tag = soup.select_one("div.item.published span")
    published_time = published_tag['title'] if published_tag and 'title' in published_tag.attrs else 'N/A'

    # 7. Mô tả
    description_tag = soup.select_one("section.section.post-main-content div.section-content")
    description = description_tag.get_text(separator="\n").strip() if description_tag else 'N/A'
    
    # 8. Ngày hết hạn
    expiration_date_tag = soup.select_one("table.table tr:nth-child(8) td time")
    expiration_date = expiration_date_tag.get_text() if expiration_date_tag else 'N/A'

    # 9. Loại tin rao (lấy nội dung trong cột thứ 2)
    listing_type_tag = soup.select_one("tr:contains('Loại tin rao:') td:nth-child(2)")
    listing_type = listing_type_tag.get_text().strip() if listing_type_tag else 'N/A'

    # 10. Đối tượng thuê (lấy nội dung trong cột thứ 2)
    tenant_type_tag = soup.select_one("tr:contains('Đối tượng thuê:') td:nth-child(2)")
    tenant_type = tenant_type_tag.get_text().strip() if tenant_type_tag else 'N/A'


    # Trả về dictionary chứa tất cả các thông tin
    return {
        'room_id': room_id,
        'title': title,
        'address': address,
        'price': price,
        'area': area,
        'published_time': published_time,
        'expiration_date': expiration_date,   
        'listing_type': listing_type,         
        'tenant_type': tenant_type,
        'description': description           
    }

# %%
def scrape_all_pages(base_url, num_pages):
    all_links = []
    for page in range(1, num_pages + 1):
        page_url = f"{base_url}?page={page}" if page > 1 else base_url  # Tạo URL từng trang
        listing_links = get_listing_links(page_url)
        all_links.extend(listing_links)
        print(f"Đã lấy xong dữ liệu từ trang {page}")  # In ra để kiểm tra tiến trình
    return all_links

# %%
def scrape_all_listings(base_url, num_pages):
    # Lấy tất cả các đường dẫn bài đăng
    all_links = scrape_all_pages(base_url, num_pages)

    # Trích xuất thông tin từ từng bài đăng
    all_room_details = []
    for link in all_links:
        room_details = get_room_details(link)
        all_room_details.append(room_details)
        
    df = pd.DataFrame(all_room_details)
    
    return all_room_details

# %%
base_url = "https://phongtro123.com/tinh-thanh/ho-chi-minh"  # Trang chính
num_pages = 550  # Số lượng trang bạn muốn scraping

# %%
# Scraping dữ liệu từ nhiều trang
room_data = scrape_all_listings(base_url, num_pages)
# Out:
# Đã lấy xong dữ liệu từ trang 1
# Đã lấy xong dữ liệu từ trang 2
# Đã lấy xong dữ liệu từ trang 3
# Đã lấy xong dữ liệu từ trang 4
# Đã lấy xong dữ liệu từ trang 5
# Đã lấy xong dữ liệu từ trang 6
# Đã lấy xong dữ liệu từ trang 7
# Đã lấy xong dữ liệu từ trang 8
# Đã lấy xong dữ liệu từ trang 9
# Đã lấy xong dữ liệu từ trang 10
# Đã lấy xong dữ liệu từ trang 11
# Đã lấy xong dữ liệu từ trang 12
# Đã lấy xong dữ liệu từ trang 13
# Đã lấy xong dữ liệu từ trang 14
# Đã lấy xong dữ liệu từ trang 15
# Đã lấy xong dữ liệu từ trang 16
# Đã lấy xong dữ liệu từ trang 17
# Đã lấy xong dữ liệu từ trang 18
# Đã lấy xong dữ liệu từ trang 19
# Đã lấy xong dữ liệu từ trang 20
# Đã lấy xong dữ liệu từ trang 21
# Đã lấy xong dữ liệu từ trang 22
# Đã lấy xong dữ liệu từ trang 23
# Đã lấy xong dữ liệu từ trang 24
# Đã lấy xong dữ liệu từ trang 25
# Đã lấy xong dữ liệu từ trang 26
# Đã lấy xong dữ liệu từ trang 27
# Đã lấy xong dữ liệu từ trang 28
# Đã lấy xong dữ liệu từ trang 29
# Đã lấy xong dữ liệu từ trang 30
# Đã lấy xong dữ liệu từ trang 31
# Đã lấy xong dữ liệu từ trang 32
# Đã lấy xong dữ liệu từ trang 33
# Đã lấy xong dữ liệu từ trang 34
# Đã lấy xong dữ liệu từ trang 35
# Đã lấy xong dữ liệu từ trang 36
# Đã lấy xong dữ liệu từ trang 37
# Đã lấy xong dữ liệu từ trang 38
# Đã lấy xong dữ liệu từ trang 39
# Đã lấy xong dữ liệu từ trang 40
# Đã lấy xong dữ liệu từ trang 41
# Đã lấy xong dữ liệu từ trang 42
# Đã lấy xong dữ liệu từ trang 43
# Đã lấy xong dữ liệu từ trang 44
# Đã lấy xong dữ liệu từ trang 45
# Đã lấy xong dữ liệu từ trang 46
# Đã lấy xong dữ liệu từ trang 47
# Đã lấy xong dữ liệu từ trang 48
# Đã lấy xong dữ liệu từ trang 49
# Đã lấy xong dữ liệu từ trang 50
# Đã lấy xong dữ liệu từ trang 51
# Đã lấy xong dữ liệu từ trang 52
# Đã lấy xong dữ liệu từ trang 53
# Đã lấy xong dữ liệu từ trang 54
# Đã lấy xong dữ liệu từ trang 55
# Đã lấy xong dữ liệu từ trang 56
# Đã lấy xong dữ liệu từ trang 57
# Đã lấy xong dữ liệu từ trang 58
# Đã lấy xong dữ liệu từ trang 59
# Đã lấy xong dữ liệu từ trang 60
# Đã lấy xong dữ liệu từ trang 61
# Đã lấy xong dữ liệu từ trang 62
# Đã lấy xong dữ liệu từ trang 63
# Đã lấy xong dữ liệu từ trang 64
# Đã lấy xong dữ liệu từ trang 65
# Đã lấy xong dữ liệu từ trang 66
# Đã lấy xong dữ liệu từ trang 67
# Đã lấy xong dữ liệu từ trang 68
# Đã lấy xong dữ liệu từ trang 69
# Đã lấy xong dữ liệu từ trang 70
# Đã lấy xong dữ liệu từ trang 71
# Đã lấy xong dữ liệu từ trang 72
# Đã lấy xong dữ liệu từ trang 73
# Đã lấy xong dữ liệu từ trang 74
# Đã lấy xong dữ liệu từ trang 75
# Đã lấy xong dữ liệu từ trang 76
# Đã lấy xong dữ liệu từ trang 77
# Đã lấy xong dữ liệu từ trang 78
# Đã lấy xong dữ liệu từ trang 79
# Đã lấy xong dữ liệu từ trang 80
# Đã lấy xong dữ liệu từ trang 81
# Đã lấy xong dữ liệu từ trang 82
# Đã lấy xong dữ liệu từ trang 83
# Đã lấy xong dữ liệu từ trang 84
# Đã lấy xong dữ liệu từ trang 85
# Đã lấy xong dữ liệu từ trang 86
# Đã lấy xong dữ liệu từ trang 87
# Đã lấy xong dữ liệu từ trang 88
# Đã lấy xong dữ liệu từ trang 89
# Đã lấy xong dữ liệu từ trang 90
# Đã lấy xong dữ liệu từ trang 91
# Đã lấy xong dữ liệu từ trang 92
# Đã lấy xong dữ liệu từ trang 93
# Đã lấy xong dữ liệu từ trang 94
# Đã lấy xong dữ liệu từ trang 95
# Đã lấy xong dữ liệu từ trang 96
# Đã lấy xong dữ liệu từ trang 97
# Đã lấy xong dữ liệu từ trang 98
# Đã lấy xong dữ liệu từ trang 99
# Đã lấy xong dữ liệu từ trang 100
# Đã lấy xong dữ liệu từ trang 101
# Đã lấy xong dữ liệu từ trang 102
# Đã lấy xong dữ liệu từ trang 103
# Đã lấy xong dữ liệu từ trang 104
# Đã lấy xong dữ liệu từ trang 105
# Đã lấy xong dữ liệu từ trang 106
# Đã lấy xong dữ liệu từ trang 107
# Đã lấy xong dữ liệu từ trang 108
# Đã lấy xong dữ liệu từ trang 109
# Đã lấy xong dữ liệu từ trang 110
# Đã lấy xong dữ liệu từ trang 111
# Đã lấy xong dữ liệu từ trang 112
# Đã lấy xong dữ liệu từ trang 113
# Đã lấy xong dữ liệu từ trang 114
# Đã lấy xong dữ liệu từ trang 115
# Đã lấy xong dữ liệu từ trang 116
# Đã lấy xong dữ liệu từ trang 117
# Đã lấy xong dữ liệu từ trang 118
# Đã lấy xong dữ liệu từ trang 119
# Đã lấy xong dữ liệu từ trang 120
# Đã lấy xong dữ liệu từ trang 121
# Đã lấy xong dữ liệu từ trang 122
# Đã lấy xong dữ liệu từ trang 123
# Đã lấy xong dữ liệu từ trang 124
# Đã lấy xong dữ liệu từ trang 125
# Đã lấy xong dữ liệu từ trang 126
# Đã lấy xong dữ liệu từ trang 127
# Đã lấy xong dữ liệu từ trang 128
# Đã lấy xong dữ liệu từ trang 129
# Đã lấy xong dữ liệu từ trang 130
# Đã lấy xong dữ liệu từ trang 131
# Đã lấy xong dữ liệu từ trang 132
# Đã lấy xong dữ liệu từ trang 133
# Đã lấy xong dữ liệu từ trang 134
# Đã lấy xong dữ liệu từ trang 135
# Đã lấy xong dữ liệu từ trang 136
# Đã lấy xong dữ liệu từ trang 137
# Đã lấy xong dữ liệu từ trang 138
# Đã lấy xong dữ liệu từ trang 139
# Đã lấy xong dữ liệu từ trang 140
# Đã lấy xong dữ liệu từ trang 141
# Đã lấy xong dữ liệu từ trang 142
# Đã lấy xong dữ liệu từ trang 143
# Đã lấy xong dữ liệu từ trang 144
# Đã lấy xong dữ liệu từ trang 145
# Đã lấy xong dữ liệu từ trang 146
# Đã lấy xong dữ liệu từ trang 147
# Đã lấy xong dữ liệu từ trang 148
# Đã lấy xong dữ liệu từ trang 149
# Đã lấy xong dữ liệu từ trang 150
# Đã lấy xong dữ liệu từ trang 151
# Đã lấy xong dữ liệu từ trang 152
# Đã lấy xong dữ liệu từ trang 153
# Đã lấy xong dữ liệu từ trang 154
# Đã lấy xong dữ liệu từ trang 155
# Đã lấy xong dữ liệu từ trang 156
# Đã lấy xong dữ liệu từ trang 157
# Đã lấy xong dữ liệu từ trang 158
# Đã lấy xong dữ liệu từ trang 159
# Đã lấy xong dữ liệu từ trang 160
# Đã lấy xong dữ liệu từ trang 161
# Đã lấy xong dữ liệu từ trang 162
# Đã lấy xong dữ liệu từ trang 163
# Đã lấy xong dữ liệu từ trang 164
# Đã lấy xong dữ liệu từ trang 165
# Đã lấy xong dữ liệu từ trang 166
# Đã lấy xong dữ liệu từ trang 167
# Đã lấy xong dữ liệu từ trang 168
# Đã lấy xong dữ liệu từ trang 169
# Đã lấy xong dữ liệu từ trang 170
# Đã lấy xong dữ liệu từ trang 171
# Đã lấy xong dữ liệu từ trang 172
# Đã lấy xong dữ liệu từ trang 173
# Đã lấy xong dữ liệu từ trang 174
# Đã lấy xong dữ liệu từ trang 175
# Đã lấy xong dữ liệu từ trang 176
# Đã lấy xong dữ liệu từ trang 177
# Đã lấy xong dữ liệu từ trang 178
# Đã lấy xong dữ liệu từ trang 179
# Đã lấy xong dữ liệu từ trang 180
# Đã lấy xong dữ liệu từ trang 181
# Đã lấy xong dữ liệu từ trang 182
# Đã lấy xong dữ liệu từ trang 183
# Đã lấy xong dữ liệu từ trang 184
# Đã lấy xong dữ liệu từ trang 185
# Đã lấy xong dữ liệu từ trang 186
# Đã lấy xong dữ liệu từ trang 187
# Đã lấy xong dữ liệu từ trang 188
# Đã lấy xong dữ liệu từ trang 189
# Đã lấy xong dữ liệu từ trang 190
# Đã lấy xong dữ liệu từ trang 191
# Đã lấy xong dữ liệu từ trang 192
# Đã lấy xong dữ liệu từ trang 193
# Đã lấy xong dữ liệu từ trang 194
# Đã lấy xong dữ liệu từ trang 195
# Đã lấy xong dữ liệu từ trang 196
# Đã lấy xong dữ liệu từ trang 197
# Đã lấy xong dữ liệu từ trang 198
# Đã lấy xong dữ liệu từ trang 199
# Đã lấy xong dữ liệu từ trang 200
# Đã lấy xong dữ liệu từ trang 201
# Đã lấy xong dữ liệu từ trang 202
# Đã lấy xong dữ liệu từ trang 203
# Đã lấy xong dữ liệu từ trang 204
# Đã lấy xong dữ liệu từ trang 205
# Đã lấy xong dữ liệu từ trang 206
# Đã lấy xong dữ liệu từ trang 207
# Đã lấy xong dữ liệu từ trang 208
# Đã lấy xong dữ liệu từ trang 209
# Đã lấy xong dữ liệu từ trang 210
# Đã lấy xong dữ liệu từ trang 211
# Đã lấy xong dữ liệu từ trang 212
# Đã lấy xong dữ liệu từ trang 213
# Đã lấy xong dữ liệu từ trang 214
# Đã lấy xong dữ liệu từ trang 215
# Đã lấy xong dữ liệu từ trang 216
# Đã lấy xong dữ liệu từ trang 217
# Đã lấy xong dữ liệu từ trang 218
# Đã lấy xong dữ liệu từ trang 219
# Đã lấy xong dữ liệu từ trang 220
# Đã lấy xong dữ liệu từ trang 221
# Đã lấy xong dữ liệu từ trang 222
# Đã lấy xong dữ liệu từ trang 223
# Đã lấy xong dữ liệu từ trang 224
# Đã lấy xong dữ liệu từ trang 225
# Đã lấy xong dữ liệu từ trang 226
# Đã lấy xong dữ liệu từ trang 227
# Đã lấy xong dữ liệu từ trang 228
# Đã lấy xong dữ liệu từ trang 229
# Đã lấy xong dữ liệu từ trang 230
# Đã lấy xong dữ liệu từ trang 231
# Đã lấy xong dữ liệu từ trang 232
# Đã lấy xong dữ liệu từ trang 233
# Đã lấy xong dữ liệu từ trang 234
# Đã lấy xong dữ liệu từ trang 235
# Đã lấy xong dữ liệu từ trang 236
# Đã lấy xong dữ liệu từ trang 237
# Đã lấy xong dữ liệu từ trang 238
# Đã lấy xong dữ liệu từ trang 239
# Đã lấy xong dữ liệu từ trang 240
# Đã lấy xong dữ liệu từ trang 241
# Đã lấy xong dữ liệu từ trang 242
# Đã lấy xong dữ liệu từ trang 243
# Đã lấy xong dữ liệu từ trang 244
# Đã lấy xong dữ liệu từ trang 245
# Đã lấy xong dữ liệu từ trang 246
# Đã lấy xong dữ liệu từ trang 247
# Đã lấy xong dữ liệu từ trang 248
# Đã lấy xong dữ liệu từ trang 249
# Đã lấy xong dữ liệu từ trang 250
# Đã lấy xong dữ liệu từ trang 251
# Đã lấy xong dữ liệu từ trang 252
# Đã lấy xong dữ liệu từ trang 253
# Đã lấy xong dữ liệu từ trang 254
# Đã lấy xong dữ liệu từ trang 255
# Đã lấy xong dữ liệu từ trang 256
# Đã lấy xong dữ liệu từ trang 257
# Đã lấy xong dữ liệu từ trang 258
# Đã lấy xong dữ liệu từ trang 259
# Đã lấy xong dữ liệu từ trang 260
# Đã lấy xong dữ liệu từ trang 261
# Đã lấy xong dữ liệu từ trang 262
# Đã lấy xong dữ liệu từ trang 263
# Đã lấy xong dữ liệu từ trang 264
# Đã lấy xong dữ liệu từ trang 265
# Đã lấy xong dữ liệu từ trang 266
# Đã lấy xong dữ liệu từ trang 267
# Đã lấy xong dữ liệu từ trang 268
# Đã lấy xong dữ liệu từ trang 269
# Đã lấy xong dữ liệu từ trang 270
# Đã lấy xong dữ liệu từ trang 271
# Đã lấy xong dữ liệu từ trang 272
# Đã lấy xong dữ liệu từ trang 273
# Đã lấy xong dữ liệu từ trang 274
# Đã lấy xong dữ liệu từ trang 275
# Đã lấy xong dữ liệu từ trang 276
# Đã lấy xong dữ liệu từ trang 277
# Đã lấy xong dữ liệu từ trang 278
# Đã lấy xong dữ liệu từ trang 279
# Đã lấy xong dữ liệu từ trang 280
# Đã lấy xong dữ liệu từ trang 281
# Đã lấy xong dữ liệu từ trang 282
# Đã lấy xong dữ liệu từ trang 283
# Đã lấy xong dữ liệu từ trang 284
# Đã lấy xong dữ liệu từ trang 285
# Đã lấy xong dữ liệu từ trang 286
# Đã lấy xong dữ liệu từ trang 287
# Đã lấy xong dữ liệu từ trang 288
# Đã lấy xong dữ liệu từ trang 289
# Đã lấy xong dữ liệu từ trang 290
# Đã lấy xong dữ liệu từ trang 291
# Đã lấy xong dữ liệu từ trang 292
# Đã lấy xong dữ liệu từ trang 293
# Đã lấy xong dữ liệu từ trang 294
# Đã lấy xong dữ liệu từ trang 295
# Đã lấy xong dữ liệu từ trang 296
# Đã lấy xong dữ liệu từ trang 297
# Đã lấy xong dữ liệu từ trang 298
# Đã lấy xong dữ liệu từ trang 299
# Đã lấy xong dữ liệu từ trang 300
# Đã lấy xong dữ liệu từ trang 301
# Đã lấy xong dữ liệu từ trang 302
# Đã lấy xong dữ liệu từ trang 303
# Đã lấy xong dữ liệu từ trang 304
# Đã lấy xong dữ liệu từ trang 305
# Đã lấy xong dữ liệu từ trang 306
# Đã lấy xong dữ liệu từ trang 307
# Đã lấy xong dữ liệu từ trang 308
# Đã lấy xong dữ liệu từ trang 309
# Đã lấy xong dữ liệu từ trang 310
# Đã lấy xong dữ liệu từ trang 311
# Đã lấy xong dữ liệu từ trang 312
# Đã lấy xong dữ liệu từ trang 313
# Đã lấy xong dữ liệu từ trang 314
# Đã lấy xong dữ liệu từ trang 315
# Đã lấy xong dữ liệu từ trang 316
# Đã lấy xong dữ liệu từ trang 317
# Đã lấy xong dữ liệu từ trang 318
# Đã lấy xong dữ liệu từ trang 319
# Đã lấy xong dữ liệu từ trang 320
# Đã lấy xong dữ liệu từ trang 321
# Đã lấy xong dữ liệu từ trang 322
# Đã lấy xong dữ liệu từ trang 323
# Đã lấy xong dữ liệu từ trang 324
# Đã lấy xong dữ liệu từ trang 325
# Đã lấy xong dữ liệu từ trang 326
# Đã lấy xong dữ liệu từ trang 327
# Đã lấy xong dữ liệu từ trang 328
# Đã lấy xong dữ liệu từ trang 329
# Đã lấy xong dữ liệu từ trang 330
# Đã lấy xong dữ liệu từ trang 331
# Đã lấy xong dữ liệu từ trang 332
# Đã lấy xong dữ liệu từ trang 333
# Đã lấy xong dữ liệu từ trang 334
# Đã lấy xong dữ liệu từ trang 335
# Đã lấy xong dữ liệu từ trang 336
# Đã lấy xong dữ liệu từ trang 337
# Đã lấy xong dữ liệu từ trang 338
# Đã lấy xong dữ liệu từ trang 339
# Đã lấy xong dữ liệu từ trang 340
# Đã lấy xong dữ liệu từ trang 341
# Đã lấy xong dữ liệu từ trang 342
# Đã lấy xong dữ liệu từ trang 343
# Đã lấy xong dữ liệu từ trang 344
# Đã lấy xong dữ liệu từ trang 345
# Đã lấy xong dữ liệu từ trang 346
# Đã lấy xong dữ liệu từ trang 347
# Đã lấy xong dữ liệu từ trang 348
# Đã lấy xong dữ liệu từ trang 349
# Đã lấy xong dữ liệu từ trang 350
# Đã lấy xong dữ liệu từ trang 351
# Đã lấy xong dữ liệu từ trang 352
# Đã lấy xong dữ liệu từ trang 353
# Đã lấy xong dữ liệu từ trang 354
# Đã lấy xong dữ liệu từ trang 355
# Đã lấy xong dữ liệu từ trang 356
# Đã lấy xong dữ liệu từ trang 357
# Đã lấy xong dữ liệu từ trang 358
# Đã lấy xong dữ liệu từ trang 359
# Đã lấy xong dữ liệu từ trang 360
# Đã lấy xong dữ liệu từ trang 361
# Đã lấy xong dữ liệu từ trang 362
# Đã lấy xong dữ liệu từ trang 363
# Đã lấy xong dữ liệu từ trang 364
# Đã lấy xong dữ liệu từ trang 365
# Đã lấy xong dữ liệu từ trang 366
# Đã lấy xong dữ liệu từ trang 367
# Đã lấy xong dữ liệu từ trang 368
# Đã lấy xong dữ liệu từ trang 369
# Đã lấy xong dữ liệu từ trang 370
# Đã lấy xong dữ liệu từ trang 371
# Đã lấy xong dữ liệu từ trang 372
# Đã lấy xong dữ liệu từ trang 373
# Đã lấy xong dữ liệu từ trang 374
# Đã lấy xong dữ liệu từ trang 375
# Đã lấy xong dữ liệu từ trang 376
# Đã lấy xong dữ liệu từ trang 377
# Đã lấy xong dữ liệu từ trang 378
# Đã lấy xong dữ liệu từ trang 379
# Đã lấy xong dữ liệu từ trang 380
# Đã lấy xong dữ liệu từ trang 381
# Đã lấy xong dữ liệu từ trang 382
# Đã lấy xong dữ liệu từ trang 383
# Đã lấy xong dữ liệu từ trang 384
# Đã lấy xong dữ liệu từ trang 385
# Đã lấy xong dữ liệu từ trang 386
# Đã lấy xong dữ liệu từ trang 387
# Đã lấy xong dữ liệu từ trang 388
# Đã lấy xong dữ liệu từ trang 389
# Đã lấy xong dữ liệu từ trang 390
# Đã lấy xong dữ liệu từ trang 391
# Đã lấy xong dữ liệu từ trang 392
# Đã lấy xong dữ liệu từ trang 393
# Đã lấy xong dữ liệu từ trang 394
# Đã lấy xong dữ liệu từ trang 395
# Đã lấy xong dữ liệu từ trang 396
# Đã lấy xong dữ liệu từ trang 397
# Đã lấy xong dữ liệu từ trang 398
# Đã lấy xong dữ liệu từ trang 399
# Đã lấy xong dữ liệu từ trang 400
# Đã lấy xong dữ liệu từ trang 401
# Đã lấy xong dữ liệu từ trang 402
# Đã lấy xong dữ liệu từ trang 403
# Đã lấy xong dữ liệu từ trang 404
# Đã lấy xong dữ liệu từ trang 405
# Đã lấy xong dữ liệu từ trang 406
# Đã lấy xong dữ liệu từ trang 407
# Đã lấy xong dữ liệu từ trang 408
# Đã lấy xong dữ liệu từ trang 409
# Đã lấy xong dữ liệu từ trang 410
# Đã lấy xong dữ liệu từ trang 411
# Đã lấy xong dữ liệu từ trang 412
# Đã lấy xong dữ liệu từ trang 413
# Đã lấy xong dữ liệu từ trang 414
# Đã lấy xong dữ liệu từ trang 415
# Đã lấy xong dữ liệu từ trang 416
# Đã lấy xong dữ liệu từ trang 417
# Đã lấy xong dữ liệu từ trang 418
# Đã lấy xong dữ liệu từ trang 419
# Đã lấy xong dữ liệu từ trang 420
# Đã lấy xong dữ liệu từ trang 421
# Đã lấy xong dữ liệu từ trang 422
# Đã lấy xong dữ liệu từ trang 423
# Đã lấy xong dữ liệu từ trang 424
# Đã lấy xong dữ liệu từ trang 425
# Đã lấy xong dữ liệu từ trang 426
# Đã lấy xong dữ liệu từ trang 427
# Đã lấy xong dữ liệu từ trang 428
# Đã lấy xong dữ liệu từ trang 429
# Đã lấy xong dữ liệu từ trang 430
# Đã lấy xong dữ liệu từ trang 431
# Đã lấy xong dữ liệu từ trang 432
# Đã lấy xong dữ liệu từ trang 433
# Đã lấy xong dữ liệu từ trang 434
# Đã lấy xong dữ liệu từ trang 435
# Đã lấy xong dữ liệu từ trang 436
# Đã lấy xong dữ liệu từ trang 437
# Đã lấy xong dữ liệu từ trang 438
# Đã lấy xong dữ liệu từ trang 439
# Đã lấy xong dữ liệu từ trang 440
# Đã lấy xong dữ liệu từ trang 441
# Đã lấy xong dữ liệu từ trang 442
# Đã lấy xong dữ liệu từ trang 443
# Đã lấy xong dữ liệu từ trang 444
# Đã lấy xong dữ liệu từ trang 445
# Đã lấy xong dữ liệu từ trang 446
# Đã lấy xong dữ liệu từ trang 447
# Đã lấy xong dữ liệu từ trang 448
# Đã lấy xong dữ liệu từ trang 449
# Đã lấy xong dữ liệu từ trang 450
# Đã lấy xong dữ liệu từ trang 451
# Đã lấy xong dữ liệu từ trang 452
# Đã lấy xong dữ liệu từ trang 453
# Đã lấy xong dữ liệu từ trang 454
# Đã lấy xong dữ liệu từ trang 455
# Đã lấy xong dữ liệu từ trang 456
# Đã lấy xong dữ liệu từ trang 457
# Đã lấy xong dữ liệu từ trang 458
# Đã lấy xong dữ liệu từ trang 459
# Đã lấy xong dữ liệu từ trang 460
# Đã lấy xong dữ liệu từ trang 461
# Đã lấy xong dữ liệu từ trang 462
# Đã lấy xong dữ liệu từ trang 463
# Đã lấy xong dữ liệu từ trang 464
# Đã lấy xong dữ liệu từ trang 465
# Đã lấy xong dữ liệu từ trang 466
# Đã lấy xong dữ liệu từ trang 467
# Đã lấy xong dữ liệu từ trang 468
# Đã lấy xong dữ liệu từ trang 469
# Đã lấy xong dữ liệu từ trang 470
# Đã lấy xong dữ liệu từ trang 471
# Đã lấy xong dữ liệu từ trang 472
# Đã lấy xong dữ liệu từ trang 473
# Đã lấy xong dữ liệu từ trang 474
# Đã lấy xong dữ liệu từ trang 475
# Đã lấy xong dữ liệu từ trang 476
# Đã lấy xong dữ liệu từ trang 477
# Đã lấy xong dữ liệu từ trang 478
# Đã lấy xong dữ liệu từ trang 479
# Đã lấy xong dữ liệu từ trang 480
# Đã lấy xong dữ liệu từ trang 481
# Đã lấy xong dữ liệu từ trang 482
# Đã lấy xong dữ liệu từ trang 483
# Đã lấy xong dữ liệu từ trang 484
# Đã lấy xong dữ liệu từ trang 485
# Đã lấy xong dữ liệu từ trang 486
# Đã lấy xong dữ liệu từ trang 487
# Đã lấy xong dữ liệu từ trang 488
# Đã lấy xong dữ liệu từ trang 489
# Đã lấy xong dữ liệu từ trang 490
# Đã lấy xong dữ liệu từ trang 491
# Đã lấy xong dữ liệu từ trang 492
# Đã lấy xong dữ liệu từ trang 493
# Đã lấy xong dữ liệu từ trang 494
# Đã lấy xong dữ liệu từ trang 495
# Đã lấy xong dữ liệu từ trang 496
# Đã lấy xong dữ liệu từ trang 497
# Đã lấy xong dữ liệu từ trang 498
# Đã lấy xong dữ liệu từ trang 499
# Đã lấy xong dữ liệu từ trang 500
# Đã lấy xong dữ liệu từ trang 501
# Đã lấy xong dữ liệu từ trang 502
# Đã lấy xong dữ liệu từ trang 503
# Đã lấy xong dữ liệu từ trang 504
# Đã lấy xong dữ liệu từ trang 505
# Đã lấy xong dữ liệu từ trang 506
# Đã lấy xong dữ liệu từ trang 507
# Đã lấy xong dữ liệu từ trang 508
# Đã lấy xong dữ liệu từ trang 509
# Đã lấy xong dữ liệu từ trang 510
# Đã lấy xong dữ liệu từ trang 511
# Đã lấy xong dữ liệu từ trang 512
# Đã lấy xong dữ liệu từ trang 513
# Đã lấy xong dữ liệu từ trang 514
# Đã lấy xong dữ liệu từ trang 515
# Đã lấy xong dữ liệu từ trang 516
# Đã lấy xong dữ liệu từ trang 517
# Đã lấy xong dữ liệu từ trang 518
# Đã lấy xong dữ liệu từ trang 519
# Đã lấy xong dữ liệu từ trang 520
# Đã lấy xong dữ liệu từ trang 521
# Đã lấy xong dữ liệu từ trang 522
# Đã lấy xong dữ liệu từ trang 523
# Đã lấy xong dữ liệu từ trang 524
# Đã lấy xong dữ liệu từ trang 525
# Đã lấy xong dữ liệu từ trang 526
# Đã lấy xong dữ liệu từ trang 527
# Đã lấy xong dữ liệu từ trang 528
# Đã lấy xong dữ liệu từ trang 529
# Đã lấy xong dữ liệu từ trang 530
# Đã lấy xong dữ liệu từ trang 531
# Đã lấy xong dữ liệu từ trang 532
# Đã lấy xong dữ liệu từ trang 533
# Đã lấy xong dữ liệu từ trang 534
# Đã lấy xong dữ liệu từ trang 535
# Đã lấy xong dữ liệu từ trang 536
# Đã lấy xong dữ liệu từ trang 537
# Đã lấy xong dữ liệu từ trang 538
# Đã lấy xong dữ liệu từ trang 539
# Đã lấy xong dữ liệu từ trang 540
# Đã lấy xong dữ liệu từ trang 541
# Đã lấy xong dữ liệu từ trang 542
# Đã lấy xong dữ liệu từ trang 543
# Đã lấy xong dữ liệu từ trang 544
# Đã lấy xong dữ liệu từ trang 545
# Đã lấy xong dữ liệu từ trang 546
# Đã lấy xong dữ liệu từ trang 547
# Đã lấy xong dữ liệu từ trang 548
# Đã lấy xong dữ liệu từ trang 549
# Đã lấy xong dữ liệu từ trang 550
# c:\Program Files\Python39\lib\site-packages\soupsieve\css_parser.py:862: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028

# %%
df = pd.DataFrame(room_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   room_id          11000 non-null  object
#  1   title            11000 non-null  object
#  2   address          11000 non-null  object
#  3   price            11000 non-null  object
#  4   area             11000 non-null  object
#  5   published_time   11000 non-null  object
#  6   expiration_date  11000 non-null  object
#  7   listing_type     11000 non-null  object
#  8   tenant_type      11000 non-null  object
#  9   description      11000 non-null  object
# dtypes: object(10)
# memory usage: 859.5+ KB

# %%
df.head()
# Out:
#   room_id                                              title  \
# 0  649687  GẦN TRƯỜNG GTVT, NGOẠI THƯƠNG, HUTECH, HỒNG BÀ...
# 1  663051  KTX Giao Thông Vận Tải - Hutech 200m - 1.4 tri...
# 2  595869                   Ký túc xá Tân Bình bao điện nước
# 3   20126  Cho thuê phòng trọ dạng chung cư mini máy lạnh...
# 4  277630  Phòng trọ dạng căn hộ mini cao cấp tại 796 Lê ...
#
#                                              address            price  area  \
# 0  97/15 Đường Ung Văn Khiêm, Phường 25, Quận Bìn...  4.5 triệu/tháng  30m2
# 1  69/38 Nguyễn Gia Trí, Phường 25, Quận Bình Thạ...  1.4 triệu/tháng  30m2
# 2  Đường Phạm Cự Lượng, Phường 2, Quận Tân Bình, ...  1.6 triệu/tháng  30m2
# 3   Đường Hoàng Ngân, Phường 16, Quận 8, Hồ Chí Minh  1.8 triệu/tháng  18m2
# 4  796 Đường Lê Đức Thọ, Phường 15, Quận Gò Vấp, ...    3 triệu/tháng  30m2
#
#             published_time          expiration_date        listing_type  \
# 0  Thứ 6, 13:53 20/09/2024  Thứ 3, 10:30 24/09/2024  Phòng trọ, nhà trọ
# 1  Thứ 6, 00:46 20/09/2024  Thứ 6, 00:46 27/09/2024  Phòng trọ, nhà trọ
# 2  Thứ 4, 20:24 18/09/2024  Thứ 7, 20:24 21/09/2024  Phòng trọ, nhà trọ
# 3  Thứ 4, 18:31 18/09/2024  Thứ 4, 18:31 25/09/2024  Phòng trọ, nhà trọ
# 4  Thứ 3, 15:46 17/09/2024  Thứ 2, 09:38 07/10/2024  Phòng trọ, nhà trọ
#
#   tenant_type                                        description
# 0      Tất cả  - Để đảm bảo an ninh cho Sinh Viên ở Ngõ Sen g...
# 1      Tất cả  Ký túc xá tiện nghi, cách ĐH Hutech chỉ 200m g...
# 2      Tất cả  free 100% tiền phòng tháng đầu\nVị trí:\nGần c...
# 3      Tất cả  Cho thuê phòng trọ dạng chung cư mini P.16, Q....
# 4      Tất cả  Cho thuê căn hộ mini cao cấp tại 796 Lê Đức Th...

# %%
df["price"].value_counts()
# Out:
# price
# 3.5 triệu/tháng         814
# 4 triệu/tháng           787
# 4.5 triệu/tháng         724
# 3 triệu/tháng           596
# 3.8 triệu/tháng         488
#                        ...
# 4.25 triệu/tháng          1
# 4.77 triệu/tháng          1
# 5.55 triệu/tháng          1
# 2.999999 triệu/tháng      1
# 3.33 triệu/tháng          1
# Name: count, Length: 193, dtype: int64
